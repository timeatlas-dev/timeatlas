# %% [markdown]
# # Scrapbook
#
# This notebook is used for development, its content can change at any time.

# %%
import timeatlas as ta
import pandas as pd
import numpy as np
from timeatlas import plots
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
ts_1 = ta.TimeSeries.create("01-2020", "03-2020", "H")
ts_2 = ta.TimeSeries.create("02-2020", "04-2020", "min")
my_arr = [ts_1, ts_2]
tsd = ta.TimeSeriesDataset(my_arr)

# %%
tsd.resample("highest").regularize("][").data
# Out:
# [                    values
#  2020-02-01 00:00:00    NaN
#  2020-02-01 00:01:00    NaN
#  2020-02-01 00:02:00    NaN
#  2020-02-01 00:03:00    NaN
#  2020-02-01 00:04:00    NaN
#  ...                    ...
#  2020-02-29 23:56:00    NaN
#  2020-02-29 23:57:00    NaN
#  2020-02-29 23:58:00    NaN
#  2020-02-29 23:59:00    NaN
#  2020-03-01 00:00:00    NaN
#
#  [41761 rows x 1 columns],
#                      values
#  2020-02-01 00:00:00    NaN
#  2020-02-01 00:01:00    NaN
#  2020-02-01 00:02:00    NaN
#  2020-02-01 00:03:00    NaN
#  2020-02-01 00:04:00    NaN
#  ...                    ...
#  2020-02-29 23:56:00    NaN
#  2020-02-29 23:57:00    NaN
#  2020-02-29 23:58:00    NaN
#  2020-02-29 23:59:00    NaN
#  2020-03-01 00:00:00    NaN
#
#  [41761 rows x 1 columns]]

# %% [markdown]
# ## Make Predictions
#
# Some definitions:
#
# - `time series` : self-explanatory, i.e. the TimeSeries object
# - `horizon` : the duration to predict after the last value of the time series
# - `frequency`: the number of values per unit of time. Usually, the frequency is given in Pandas offset aliases (https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases)
#
# ```
#                                 horizon
#    |-------------------------|- - - - - -|
#                              |||||||||||||
#            time series         frequency
#
# ```

# %%
from timeatlas import models

# %% [markdown]
# ### Train a Facebook Prophet model

# %%
m1 = models.Prophet()
m1.fit(ts)

# %%
pts1 = m1.predict(ts)
plots.prediction(pts1, ts);

# %%
pts2 = m1.predict("1 day")
plots.prediction(pts2, ts);

# %% [markdown]
# ### Train a Linear Regressor

# %%
m2 = models.LinearRegression()
m2.fit(ts)

# %%
pts3 = m2.predict(ts)
pts3.plot()

# %%
pts4 = m2.predict("2 days")
pts4.plot()

# %%
plots.prediction(pts3, ts);

# %%
plots.prediction(pts4, ts);

# %%
## Detect Anomalies

# %%
# Detect anomalies with the fitted detector
a = d.detect(ts)

# %%
a.plot()

# %%
d.truth.plot()
d.prediction.plot()
